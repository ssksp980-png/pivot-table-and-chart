# %% [markdown]
#  **pivot table & charts**

# %% [markdown]
# 1 .  What is the purpose of a PivotTable in Excel?
#
#
# Ans - pivot tables in excel are powerful tools for summarizing and analyzing
#       larger datasets .
#
#
#
#
#
# 4 .  Explain the difference between Sorting and Filtering with an example from this dataset.
#
#
# Ana - sorting arrange the data in a specific order .
#       filtering shows only the data that meets a specific oondition .
#
#        example in data set .
#
# 7  .  Why are Dashboards important for decision-making in business analysis?
#
# Ans  - Dashboards for decision making in business analysis . they are like
#        single sorce of truth providing real time make informed decision.
